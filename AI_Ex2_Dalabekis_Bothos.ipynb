# %% [markdown]
# ## Ομάδα
#
# Στοιχεία Μέλους 1: Κωνσταντίνος Δαλαμπέκης 03120055
#
# Στοιχεία Μέλους 2: Νικόλαος Μπόθος Βουτεράκος 03120158

# %% [markdown]
# # Τεχνητή Νοημοσύνη: Εργαστηριακή Άσκηση 2
# ---
#
# Ο στόχος της εργασίας είναι η κατασκευή ενός συστήματος προτάσεων (Recommendation System) για ταινίες. Οι προτάσεις αυτές θα πηγάζουν τόσο από τα χαρακτηριστικά της ταινίας όσο και από ορισμένες αξιολογήσεις του κάθε χρήστη.
#
# Στα δεδομένα της άσκησης περιλαμβάνονται ένα αρχείο με το όνομα movies_metadata.csv το όποιο περιέχει τα χαρακτηριστικά κάθε ταινίας όπως θέμα, σκηνοθέτης ηθοποιοί, λέξεις κλειδιά κ.α. από το imdb καθώς και τα αρχεία ratings.csv τα όποια περιέχουν πραγματικές αξιολογήσεις χρηστών, χωρισμένες σε train και σε test.

# %% [markdown]
# # Εκφώνηση
# Στην παρούσα εργασία σας ζητείται να μελετήσετε και να υλοποιήσετε τα παρακάτω:<br>
#
# ### Μέρος 1
# Στο μέρος 1 και 2 θα εργαστείτε μόνο με το αρχείο movies_metadata.csv, ενώ στο μέρος τρία θα δουλέψετε και με τα αρχεία των αξιολογήσεων.
# #### Ερώτημα 1α
#
# Αρχικά θα πρέπει, αφού μελετήσετε τη δομή και τα χαρακτηριστικά του movies_metadata.csv, να κατασκευάσετε μια βάση γνώσης για την Prolog η όποια ουσιαστικά θα αποτελεί τον κόσμο με τον όποιο θα εργαστείτε στην συνέχεια. Τα κατηγορήματα που θα δημιουργηθούν θα σας βοηθήσουν και στην κατασκευή του recommender και θα είναι της μορφής:
#
# ```
# director(Movie, Director).
# genre(Movie, Genre).
# ```
# #### Ερώτημα 1β
#
# Αφού δημιουργήσετε τον κόσμο του προβλήματος, στη συνέχεια καλείστε να δημιουργήσετε, σε Prolog, απλούς κανόνες οι οποίοι θα βρίσκουν όλες τις ταινίες με:
# 1.	Κοινό θέμα (κάποιες λέξεις σχετικά με το genre κοινές)
# 2.	Αρκετά κοινό θέμα (κάποιες λιγότερες λέξεις σχετικά με το genre κοινές π.χ. 3)
# 3.	Σχετικά κοινό θέμα (λίγες λέξεις σχετικές με το genre κοινές π.χ. 1)
# 4.	Κοινός σκηνοθέτης
# 5.	Ακριβώς ίδια πλοκή (κάποιες λέξεις κλειδιά της πλοκής κοινές)
# 6.	Σχετικά ίδια πλοκή (κάποιες λιγότερες λέξεις κλειδιά κοινές)
# 7.	Ίδιους τους βασικούς ηθοποιούς (και τους 3)
# 8.	Αρκετά ίδιους βασικούς ηθοποιούς (ορισμένους βασικούς ηθοποιούς κοινούς π.χ. 2)
# 9.	Σχετικά ίδιους ηθοποιούς (π.χ. 1 από τους 3)
# 10.	Ίδια γλώσσα
# 11.	Είναι έγχρωμες ή ασπρόμαυρες
# 12. Κοινό studio παραγωγής
# 13. Κοινή χώρα παραγωγής
# 14. Ίδια δεκαετία
#
# Αξίζει να σημειωθεί ότι στα παραπάνω μπορείτε να προσθέσετε περισσότερα ερωτήματα ή να αλλάξετε την κλιμακωσιμότητα των queries (πέρα από το ίδιο, αρκετά ίδιο, σχετικά ίδιο) που θα κατασκευάσετε(π.χ. μια κλίμακα από 1 στα 5 όπου αυτό είναι δυνατόν), μιας και αυτά στην συνέχεια θα χρησιμοποιηθούν για την λειτουργία του recommender. Έτσι μπορείτε να προσθέσετε queries με τα όποια μπορεί να παράγονται καλύτερες συστάσεις  (το αρχείο movie_metadata.csv περιέχει πολλές πληροφορίες ακόμα για κάθε ταινία όπως έτος κυκλοφορίας, βαθμολογία στο imdb, facebοok_likes κ.α.). Το συγκεκριμένο μέρος εργασίας είναι προπαρασκευαστικό οπότε όσο καλύτερα και πλουσιότερα τα ερωτήματα που θα φτιάξετε σε αυτό το μέρος τόσο καλύτερη θα είναι η απόδοσή των συστημάτων συστάσεων των επόμενων ερωτημάτων.
#
# Περισσότερες πληροφορίες για το dataset μπορείτε να διαβάσετε σε αυτό το [Link](https://www.kaggle.com/georgefila/movies-metadata).
# ### Μέρος 2: Recommendation System
# Στο σημείο αυτό καλείστε με βάση αυτά που κάνατε στο μέρος 1 να κατασκευάσετε queries τα όποια θα σας επιστρέφουν παρόμοιες (σε χαρακτηριστικά) ταινίες. Τα ερωτήματα αυτά θα είναι κλιμακούμενα, δηλαδή θα υπάρχουν ερωτήματα που επιστρέφουν αρκετά κοινές ταινίες αλλά και που επιστρέφουν λιγότερο και λιγότερο κοινές (σε μια κλίμακα π.χ. από 1 σε 5). Για παράδειγμα:
#
# ```
# find_simmilar_movies_5("Pirates Of The Caribbean", M).
# M = "Pirates Of The Caribbean: On Stranger Tides"
# M = "The Chronicles Of Narnia"
# M = "Prince Of Persia: The Sands Of Time"
# ...
# ```
# Για παράδειγμα, το παραπάνω ερώτημα θα επιστρέφει αρκετά κοινές σε περιεχόμενο ταινίες με την ταινια "Pirates Of The Caribbean". Θα υπάρχουν και αντίστοιχα ερωτήματα που θα βρίσκουν λιγότερο όμοιες ταινίες. Ο δείκτης ομοιότητας των ταινιών είναι αυθαίρετος και μπορείτε να τον ορίσετε εσείς όπως θέλετε, αρκεί να υπάρχει κάποια λογική σύνδεση με τα δεδομένα που περιέχονται στο αρχείο movies_metadata.csv.
#
# Συνεπώς η συνάρτηση που θα κάνει τις προτάσεις (recommendation) με είσοδο μια ταινία πρέπει να επιστρέφει-εκτυπώνει μια λίστα με τις προτεινόμενες ταινίες κατά φθίνουσα σειρά ομοιότητας.
#
#
# ###3ο Μέρος: Recommendation System Με βάση τις προτιμήσεις - Αξιολογήσεις του χρήστη
#
#
# Σε αυτό το σημείο θα εργαστείτε με τα αρχεία ratings τα όποια περιέχουν αξιολογήσεις (από 1 μέχρι 5) για τις παραπάνω ταινίες. Το προηγούμενο σύστημα συστάσεων προτείνει στον χρήστη ταινίες αποκλειστικά με βάση την ομοιότητά τους. Σε αυτό το σημείο θα γίνει μια αναβάθμιση του συστήματος έτσι ώστε να παράγονται καλύτερες  συστάσεις οι όποιες θα λαμβάνουν υπόψιν και τις προτιμήσεις του χρήστη, οι όποιες θα εξάγονται από τις αξιολογήσεις που έχει κάνει μέχρι στιγμής.
#
# Η εκπαίδευση του recommender θα γίνεται ως εξής:
#
# Για κάθε ταινία θα υπάρχει ένα score το όποιο αρχικά θε είναι ίσο με 0 και θα διαμορφώνεται από τις αξιολογήσεις κάθε user. Έτσι για έναν χρήστη με βάση τις αξιολογήσεις που υπάρχουν στο αρχείο train_ratings θα πρέπει:
#
# 1.	Για κάθε ταινία που έχει βαθμολογήσει να βρίσκονται οι κοινές ταινίες ανά κλίμακα και στο μέχρι τώρα σκορ κάθε παρόμοιας ταινίας θα προστίθεται ένα βάρος το όποιο θα μπορούσε να είναι το ποσοστό ομοιότητας της ταινίας (δηλαδή ένα βάρος για κάθε κλίμακα, αν δύο ταινίες μοιάζουν ενισχύουμε το βάρος που προσθέτουμε από το να μοιάζουν λιγότερο) επί τον βαθμό που έχει βάλει ο χρήστης για την αρχική ταινία (διαφορετικό είναι ο χρήστης να έχει βάλει 5/5 ή 1/5 σε μια ταινία από 3/5).
#
# 2. Στη συνέχεια, ανάλογα με το σκορ που έχει σχηματιστεί για κάθε ταινία, θα επιλέγεται αν αυτή θα μπορούσε να είναι προτεινόμενη για τον χρήστη ή όχι και θα μετράμε το πόσο καλά τα πήγε το σύστήμά μας με βάση ορισμένες μετρικές.
#
# Η λογική πίσω από την παραπάνω διαδικασία είναι ότι παρόμοιες ταινίες θα έχουν ανάλογο βαθμό. Για παράδειγμα αν ένας χρήστης έχει αξιολογήσει αρκετές  ταινίες οι όποιες είναι sci-fiction με 5/5 τότε μια ταίνια sci-fiction την όποια δεν έχει δεί λογικά θα του αρέσει και θα έπρεπε να την προτείνουμε.
#
# Μετά την εκπαίδευση του συστήματος σας καλείστε να δοκιμάσετε τον recommender που κατασκευάσατε στην πράξη. Για τον σκοπό αυτό θα φορτώσετε το αρχείο test_ratings.csv όπου περιέχονται οι αξιολογήσεις του ίδιου χρήστη για άλλες ταινίες. Το σύστημά σας πρέπει να προβλέπει αν μια ταινία θα πρέπει να προταθεί στον χρήστη. Μια ταίνια θεωρούμε οτι προτείνεται στον  χρήστη, αν έχει βαθμό μεγαλύτερο του 3 στο test_ratings. Συνεπώς για την επίβλεψη του συστήματός σας θα πρέπει για κάθε μια από τις ταινίες του αρχείου test_ratings.csv να προβλέψετε εάν θα αρέσει στο χρήστη ή όχι ώστε να την προτείνετε.
#
# ΠΡΟΣΟΧΗ! Η "βαθμολογία" που θα υπολογίσετε για κάθε ταινία κατά το training δεν είναι απαραίτητα πρόβλεψη της βαθμολογίας που θα έβαζε ο χρήστης.
#
# Στην συνέχεια, σε συνδιασμό με τις πραγματικές απαντήσεις του χρήστη θα αξιολογήσετε το σύστημά σας χρησιμοποιόντας τις μετρικές: precision, recall, f1 οι οποίες είναι οι πλέον γνωστές μετρικές και ευρέως χρησιμοποιούμενες τεχνικές για την επίβλεψη-μέτρηση απόδοσης ανάλογων συστημάτων.
#
# 1. Precision: Δείχνει πόσο ακριβές είναι το σύστημα. Υπολογίζει πόσα από τα στιγμιότυπα τα όποια προβλέψαμε ότι ανήκουν σε μια κλάση όντως ανήκουν σε αυτή. Η μετρική αυτή μας δίνει μια εικόνα σχετικά με τον αριθμό των ταινίων που προβλέψαμε ως προτεινόμενες ενώ δεν θα έπρεπε.
#
# 2. Recall: Υπολογίζει πόσα από τα στιγμιότυπα που ανήκουν σε μια κλάση (π.χ. προτεινόμενες ταινίες) προβλέφθηκαν σωστά.
#
# 3. F1: Είναι ένας μέσος μεταξύ των παραπάνω δυο μετρικών, έτσι ώστε να διατηρείται μια ισορροπία μεταξύ τους. Υπολογίζεται από την παρακάτω σχέση:
#
# $$F_1=2\frac{Precision\times{Recall}}{Precision+Recall}$$
#
# Οι παραπάνω συναρτήσεις παρέχονται από την βιβλιοθήκη scikit-learn.
#
# Τέλος για την καλύτερη επίβλεψη του συστήματος σας μπορείτε να εκπαιδεύσετε  τον recommender σας με ένα υποσύνολο ταινίων από ελάχιστες, λίγες μέχρι και πολλές (π.χ. 3, 5, 10, 50, ...) για να μελετήσετε κατά πόσο σας βοηθούν οι επιπλέον αξιολογήσεις κάθε φορά (δηλαδή κατά πόσο βελτιώνονται οι παραπάνω μετρικές στο test set).
#
# Έτσι π.χ. μπορείτε να εντοπίσετε περιπτώσεις όπως για παράδειγμα ότι με έναν recommender μπορεί να μην επιτυγχάνετε πολύ υψηλό σκορ όσο με άλλους, αλλά το βέλτιστο σκόρ σας επιτυγχάνεται πολύ γρηγόρα π.χ. με μόνο 10 ταινίες αντί 100. Έτσι για παράδειγμα αν ο αλγόριθμος τα πηγαίνει πολύ καλά για τρεις ταινίες και στη συνέχεια το σκορ βελτιώνεται ελάχιστα τότε αυτός ενδείκνυται για ένα σύστημα συστάσεων για νέους χρήστες όπου δεδομένου λίγων ταινιών ο αλγόριθμος είναι σε θέση να το να προτείνει καλές συστάσεις. Ενώ αν η καλύτερη απόδοση του αλγορίθμου σας είναι βέλτιστη με περισσότερες ταινίες π.χ. 50 τότε αυτός ο αλγόριθμος συστάσεων ενδείκνυται για παλιούς χρήστες με πολλές αξιολόγησεις.

# %% [markdown]
# ---
# ## Κατασκευή Περιβάλλοντος Εργασίας
# ---
# ### Διάβασμα Αρχείων στο Colab (Μόνο για το Colab)
# Αν η υλοποίηση γίνει στο google colab τότε μπορεί να χρησιμοποιηθεί το google drive ως file system. Για να γίνει Mount το google drive τρέχουμε τον παρακάτω κώδικα και κλικάρουμε στο link που θα μας εμφανιστεί.
#
# ```
# from google.colab import drive
# drive.mount('/content/drive')
# import os
# os.listdir('/gdrive/My Drive')
# ```
# Έπειτα στην σελίδα που άνοιξε επιλέγουμε το mail μας και στο επόμενο παράθυρο που θα μας ανοίξει πατάμε Να επιτρέπεται. Στην συνέχεια αντιγράφουμε τον κωδικό που θα μας βγάλει και τον κάνουμε paste στο Input που έχει ανοίξει στο colab. Έτσι πλέον αν έχουμε ανεβάσει ένα αρχείο στο google drive μπορούμε να το βρούμε στην θέση:
#
# ```
# movies_filename = '/gdrive/My Drive/' + movies_metadata.csv
# ```
# Μπορούμε πλέον κανονικά να δουλέψουμε φτιάχνοντας φακέλους ή αρχεία και γενικότερα κάνοντας οτιδήποτε θα κάναμε αν ήμασταν τοπικά.
#
# ### Prolog μέσω Python
#
# Το πακέτο που θα χρησιμοποιηθεί για την επικοινωνία Python και Prolog είναι το pyswip (https://pypi.org/project/pyswip/). Για να δουλέψει το Pyswip  χρειάζεται να υπάρχει το Swi-Prolog το όποιο αν δουλεύουμε τοπικά πρέπει να το εγκαταστήσουμε, ακολουθώντας αντίστοιχες οδηγίες στην σελίδα του εργαλείου. Για να γίνει του Swi-Prolog η εγκατάσταση στο Google Colab πρέπει να τρέξουμε τον παρακάτω κώδικα:
#
# ```
# !sudo apt-get install software-properties-common
# !sudo apt-add-repository ppa:swi-prolog/stable
# !sudo apt-get update
# !sudo apt-get install swi-prolog
# ```
# Σε κάποιο σημείο της εκτέλεσης εμφανίζεται ένα μήνυμα ότι πρέπει να πατήσουμε enter σε ένα input για να συνεχίσει η διαδικασία. Έπειτα από αυτό η εκτέλεση θα συνεχίσει χωρίς κάποιο πρόβλημα.
#
# Τέλος πρέπει να εγκαταστήσουμε το pyswip (**όπου και να δουλεύουμε**) όπως παρακάτω:
#
# ```
# !pip isntall pyswip
# ```

# %% [markdown]
# ---
# #Κώδικας για κατασκευή περιβάλλοντος εργασίας
#
# ##Μόνο για Google Colab
#
# Κώδικας για να γίνει Mount to Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
#os.listdir('/content/drive/My Drive')

# %%
path = '/content/drive/MyDrive/Colab Notebooks/'

# %%
# %%capture
#install swi-prolog
# !sudo apt-get install software-properties-common
# !sudo apt-add-repository ppa:swi-prolog
# !sudo apt-get update
# !sudo apt-get install swi-prolog
#install pyswip
# !pip install pyswip

# %% [markdown]
# # **Μέρος 1: Μελέτη των Metadata, Δημιουργία κόσμου και των βασικών queries.**

# %%
import pandas as pd
from pyswip import Prolog

# %%
# Η βιβλιοθήκη pandas είναι χρήσιμη για την εργασία με τέτοια δεδομένα
import pandas as pd 
# Διάβασμα του αρχείου 'movie_metadata.csv' 
data = pd.read_csv(path + 'movies_metadata.csv') 
#Στο csv υπαρχούν κελία με nan τιμές
#Στις θέσεις αυτές βάζουμε 'UNK' πράγμα που  κάνουμε με την παρακάτω συνάρτηση
data.fillna("UNK", inplace=True)
# Preview the first 5 lines of the loaded data 
data.head()
# Out:
#    Unnamed: 0     budget                                    genres  \
# 0           0  237000000  Action|Adventure|Fantasy|Science Fiction
# 1           1  300000000                  Adventure|Fantasy|Action
# 2           2  245000000                    Action|Adventure|Crime
# 3           3  250000000               Action|Crime|Drama|Thriller
# 4           4  260000000          Action|Adventure|Science Fiction
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                        plot_keywords  language  \
# 0  culture clash|future|space war|space colony|so...   English
# 1  ocean|drug abuse|exotic island|east india trad...   English
# 2  spy|based on novel|secret agent|sequel|mi6|bri...  Français
# 3  dc comics|crime fighter|terrorist|secret ident...   English
# 4  based on novel|mars|medallion|space travel|pri...   English
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  ...  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577  ...
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615  ...
# 2  A cryptic message from Bond’s past sends him o...  107.376788  ...
# 3  Following the death of District Attorney Harve...  112.312950  ...
# 4  John Carter is a war-weary, former military ca...   43.926995  ...
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                 movie_title vote_average  num_voted_users  \
# 0                                    Avatar          7.2            11800
# 1  Pirates of the Caribbean: At World's End          6.9             4500
# 2                                   Spectre          6.3             4466
# 3                     The Dark Knight Rises          7.6             9106
# 4                               John Carter          6.1             2124
#
#   title_year                   country      director_name     actor_1_name  \
# 0     2009.0  United States of America      James Cameron      Zoe Saldana
# 1     2007.0  United States of America     Gore Verbinski    Orlando Bloom
# 2     2015.0            United Kingdom         Sam Mendes  Christoph Waltz
# 3     2012.0  United States of America  Christopher Nolan    Michael Caine
# 4     2012.0  United States of America     Andrew Stanton     Lynn Collins
#
#        actor_2_name       actor_3_name
# 0  Sigourney Weaver       Stephen Lang
# 1   Keira Knightley  Stellan Skarsgård
# 2       Léa Seydoux      Ralph Fiennes
# 3       Gary Oldman      Anne Hathaway
# 4   Samantha Morton       Willem Dafoe
#
# [5 rows x 27 columns]

# %%
def clean_text(text):
  text = text.replace(u'\xa0', u'')
  text = text.replace(u"'", u'')
  return text

# %%
#create World
#Ορίζουμε τον κόσμο μας
prolog = Prolog()

#Για κάθε row του πίνακα φτιάχνουμε τα κατηγορήματα που θέλουμε να αποθηκέυσουμε
#αρχικά σε μια λίστα με το όνομα literals
literals = []
movie_score = {}
for row in data.itertuples(index=True, name='Pandas'):
    
    movie_title = clean_text(getattr(row, 'movie_title'))

    for genre in getattr(row, 'genres').split("|"):
        literals.append("genre('"+ movie_title +"','"+ genre +"')")
        
    for plot_keyword in getattr(row, 'plot_keywords').split("|"):
        plot_keyword = plot_keyword.replace("'", " ")
        literals.append("plot_keyword('"+ movie_title +"','"+ plot_keyword +"')")

    if 'black and white' in getattr(row, 'plot_keywords'):
        literals.append("black_and_white('"+ movie_title +"')")
        
    literals.append("language('"+ movie_title + "','"+ getattr(row, 'language') +"')")
    
    if(getattr(row, 'duration') != "UNK"):
        literals.append(f"duration('{movie_title}','{int(getattr(row, 'duration'))}')")
        
    production_companies = getattr(row, 'production_companies')
    production_companies_data = eval(production_companies)
    production_companies_id = [d['id'] for d in production_companies_data]
    for production_company_id in production_companies_id:
        literals.append(f"production_company_id('{movie_title}','{production_company_id}')")

    for item in eval(getattr(row, 'production_countries')): 
      production_country = clean_text(item["name"])
      literals.append("production_country('"+ movie_title +"','"+ production_country + "')")
        
    if(getattr(row, 'title_year') != "UNK"):
        year = int(getattr(row, 'title_year'))
        decade = str(year - year % 10)
        literals.append("decade('"+ movie_title +"','"+ decade + "')")
    
    literals.append("country('"+ movie_title +"','"+ getattr(row, 'country') +"')")
    
    literals.append("director('"+ movie_title +"','"+ clean_text(getattr(row, 'director_name')) +"')")

    actor_1_name = clean_text(getattr(row, 'actor_1_name'))
    literals.append("actor('"+ movie_title +"','"+ actor_1_name +"')")

    actor_2_name = clean_text(getattr(row, 'actor_2_name'))
    literals.append("actor('"+ movie_title +"','"+ actor_2_name +"')")

    actor_3_name = clean_text(getattr(row, 'actor_3_name'))
    literals.append("actor('"+ movie_title +"','"+ actor_3_name +"')")


#Η Prolog θέλει τα κατηγορήματά της με την σειρά 
literals.sort()
for literal in literals:
    prolog.assertz(literal)
    #print (literal +'.')

#Επίσης μπορούμε να κάνουμε consult ένα έτοιμο αρχείο στον κόσμο όπως παρακάτω
#prolog.consult(path + "db.pl")

# %%
#Consult prolog file containing the rules
prolog.consult(path + "predicates.pl")

# %% [markdown]
# Ακολουθούν παραδείγματα για τα queries που ζητήθηκαν στο ερώτημα 1β. Στο αρχείο predicates.pl βρίσκονται τα κατηγορήματα για όλα queries που ζητήθηκαν, καθώς και οι κανόνες find_sim για τα επόμενα ερωτήματα.

# %%
q = prolog.query("sameDirector('Titanic', M)")
s = set()
for sol in q: 
  s.add(sol['M'])
q.close()
print(s)
# Out:
# {'Terminator 2: Judgment Day', 'Avatar', 'The Terminator', 'True Lies', 'The Abyss', 'Aliens'}

# %%
q = prolog.query("sameLanguage('Amour', M)")
s = set()
for sol in q: 
  s.add(sol['M'])
q.close()
print(s)
# Out:
# {'Wasabi', '1911', 'The Next Best Thing', 'Irreversible', 'Desire', 'The Princess and the Frog', 'Carlos', 'The Swindle', 'Up Close & Personal', 'Grace of Monaco', 'Rushmore', 'The Names of Love', 'The Painted Veil', 'Betty Fisher and Other Stories', 'What Just Happened', 'See Spot Run', 'Simply Irresistible', 'Pierrot le Fou', 'The Country Doctor', 'Ernest & Celestine', 'No Escape', 'Elza', 'The Widow of Saint-Pierre', 'One to Another', 'Cinco de Mayo: La Batalla', 'Le Havre', '8 Women', 'The Chorus', 'The Case of the Grinning Cat', 'The Married Woman', 'When the Cats Away', 'Somethings Gotta Give', 'Forget Me Not', 'Caramel', 'Captain America: The First Avenger', 'The Incredibles', 'Amélie', 'Slumdog Millionaire', 'Elizabeth', 'The Awakening', 'They Will Have to Kill Us First', 'Aloft', 'Tinker Tailor Soldier Spy', 'The Wolf of Wall Street', 'I Am Number Four', 'Master and Commander: The Far Side of the World', 'Boomerang', 'Intolerable Cruelty', 'The Diving Bell and the Butterfly', 'Subway', 'March of the Penguins', 'Oceans', 'The Flower of Evil', 'Little White Lies', 'Elsa & Fred', 'The Artist', 'Evil Words', 'History of the World: Part I', 'The Horseman on the Roof', 'Wild Grass', 'Fly Me to the Moon', 'Little Nicholas', 'The Walk', 'Now You See Me', 'Bottle Shock', 'Pearl Harbor', 'The Bélier Family', 'Evolution', 'Oscar and Lucinda', 'Spectre', 'The Visitors', 'Welcome to the Sticks', 'The Statement', 'Holy Motors', 'Cargo', 'Dragon Hunters', 'Shrek the Third', 'The Girl on the Train', 'The Triplets of Belleville', 'Neal n Nikki', 'Moliere', 'Guess Who', 'The Visitors II: The Corridors of Time', 'Asterix at the Olympic Games', 'Camping Sauvage', 'A Monster in Paris', 'Jumper', 'Oceans Twelve', 'The Class', 'Micmacs', 'Rise of the Guardians', 'Dirty Pretty Things', 'Silent Movie', 'Burnt', 'The Others', 'Mississippi Mermaid', 'Bright Star', 'Barbecue', 'District B13', 'Coco Before Chanel', 'The Green Mile', 'Incendies', 'The Blue Room', 'Hells Angels', 'Monty Python and the Holy Grail', 'Moulin Rouge!', 'Mozarts Sister'}

# %%
q = prolog.query("allThreeCommonActors('The Avengers', M)")
s = set()
for sol in q: 
  s.add(sol['M'])
q.close()
print(s)
# Out:
# {'Avengers: Age of Ultron'}

# %%
q = prolog.query("black_and_white(M)")
for sol in q: print(sol)
q.close()
# Out:
# {'M': 'Creative Control'}
# {'M': 'Frances Ha'}
# {'M': 'Frankenweenie'}
# {'M': 'Oceans Eleven'}
# {'M': 'Renaissance'}
# {'M': 'Sin City'}
# {'M': 'The Giver'}
# {'M': 'The Phantom of the Opera'}
# {'M': 'The Waterboy'}

# %%
q = prolog.query("commonProductionCountry('X2', M, C)")
s = set()
for sol in q: 
  s.add((sol['M'], sol['C']))
q.close()
print(s)
# Out:
# {('The Heat', 'United States of America'), ('Horse Camp', 'United States of America'), ('Dolphin Tale', 'United States of America'), ('Apocalypse Now', 'United States of America'), ('Miracle at St. Anna', 'United States of America'), ('Monsters vs Aliens', 'United States of America'), ('The Master', 'United States of America'), ('Antibirth', 'United States of America'), ('The Truman Show', 'United States of America'), ('My All American', 'United States of America'), ('The Sixth Sense', 'United States of America'), ('Cutthroat Island', 'United States of America'), ('Mercury Rising', 'United States of America'), ('Chernobyl Diaries', 'United States of America'), ('Shrek 2', 'United States of America'), ('Bringing Out the Dead', 'United States of America'), ('Jeff, Who Lives at Home', 'United States of America'), ('The Fog', 'United States of America'), ('Mulan', 'United States of America'), ('What Dreams May Come', 'United States of America'), ('Saving Private Ryan', 'United States of America'), ('Galaxy Quest', 'United States of America'), ('Graduation Day', 'United States of America'), ('Ultraviolet', 'United States of America'), ('Varsity Blues', 'United States of America'), ('Madagascar', 'United States of America'), ('The House Bunny', 'United States of America'), ('Stone', 'United States of America'), ('Battle: Los Angeles', 'United States of America'), ('The Muppet Movie', 'United States of America'), ('The Players Club', 'United States of America'), ('The Tigger Movie', 'United States of America'), ('Risen', 'United States of America'), ('Flawless', 'United States of America'), ('The Thing', 'United States of America'), ('The Game Plan', 'United States of America'), ('Eastern Promises', 'United States of America'), ('The Back-Up Plan', 'United States of America'), ('The Spy Next Door', 'United States of America'), ('Things We Lost in the Fire', 'United States of America'), ('2012', 'United States of America'), ('The Time Travelers Wife', 'United States of America'), ('A Million Ways to Die in the West', 'United States of America'), ('Jaws 2', 'United States of America'), ('Ghost Town', 'United States of America'), ('Moonlight Mile', 'United States of America'), ('Maze Runner: The Scorch Trials', 'United States of America'), ('Halloween: The Curse of Michael Myers', 'United States of America'), ('My Best Friends Wedding', 'United States of America'), ('Saving Face', 'United States of America'), ('A Beautiful Mind', 'United States of America'), ('Lord of War', 'United States of America'), ('Star Wars: Episode III - Revenge of the Sith', 'United States of America'), ('Terminator 2: Judgment Day', 'United States of America'), ('Harvard Man', 'United States of America'), ('Naturally Native', 'United States of America'), ('Flushed Away', 'United States of America'), ('Friday the 13th: The Final Chapter', 'United States of America'), ('Sex Tape', 'United States of America'), ('The Cooler', 'United States of America'), ('Ouija', 'United States of America'), ('Shanghai Noon', 'United States of America'), ('Glengarry Glen Ross', 'United States of America'), ('Killer Joe', 'United States of America'), ('Ironclad', 'United States of America'), ('Two Evil Eyes', 'United States of America'), ('The Diary of a Teenage Girl', 'United States of America'), ('Woo', 'United States of America'), ('The Scarlet Letter', 'United States of America'), ('Peaceful Warrior', 'United States of America'), ('Where the Heart Is', 'United States of America'), ('The Revenant', 'United States of America'), ('Auto Focus', 'United States of America'), ('Crocodile Dundee in Los Angeles', 'United States of America'), ('A Christmas Carol', 'United States of America'), ('Sweet November', 'United States of America'), ('The Whole Nine Yards', 'United States of America'), ('On The Downlow', 'United States of America'), ('Pushing Tin', 'United States of America'), ('Creature', 'United States of America'), ('Harry Potter and the Half-Blood Prince', 'United States of A ...

# %%
q = prolog.query("atLeastThreeCommonGenres('Thor', X)")
s = set()
for sol in q:
   s.add(sol['X'])
q.close()
print(s)
# Out:
# {'The 13th Warrior', 'Underworld: Rise of the Lycans', 'The Wolverine', 'Monkeybone', 'The Brothers Grimm', 'Final Fantasy: The Spirits Within', 'Warcraft', 'The Last Legion', 'Pirates of the Caribbean: On Stranger Tides', 'Spider-Man 2', 'Fantastic 4: Rise of the Silver Surfer', 'Clash of the Titans', '47 Ronin', 'The Borrowers', 'Brave', 'The Scorpion King', 'Dungeons & Dragons: Wrath of the Dragon God', 'Batman', 'Night at the Museum: Battle of the Smithsonian', 'The Fifth Element', 'The Amazing Spider-Man', 'Highlander', 'Thunderbirds', 'Conan the Destroyer', 'The Covenant', 'Last Action Hero', 'Cirque du Freak: The Vampires Assistant', 'Eragon', 'Small Soldiers', 'The Hobbit: The Battle of the Five Armies', 'Lara Croft Tomb Raider: The Cradle of Life', 'Superman', 'Big Trouble in Little China', 'Mystery Men', 'Jimmy Neutron: Boy Genius', 'Pirates of the Caribbean: Dead Mans Chest', 'The Mummy Returns', 'Pirates of the Caribbean: At Worlds End', 'Superman III', 'Avatar', 'Jupiter Ascending', 'The Monkey King 2', 'Dragonball Evolution', 'Pirates of the Caribbean: The Curse of the Black Pearl', 'In the Name of the King III', 'Puss in Boots', 'The Sorcerers Apprentice', 'Prince of Persia: The Sands of Time', 'The Amazing Spider-Man 2', 'In the Name of the King: A Dungeon Siege Tale', 'Spawn', 'Lara Croft: Tomb Raider', 'Conan the Barbarian', 'The Shadow', 'Pokémon: Spell of the Unknown', 'Man of Steel', 'Star Wars: Clone Wars: Volume 1', 'The Warriors Way', 'Beastmaster 2: Through the Portal of Time', 'Reign of Fire', 'How to Train Your Dragon 2', 'The Last Airbender', 'X-Men: Days of Future Past', 'Krull', 'Superman Returns', 'Blade: Trinity', 'BloodRayne', 'Jonah: A VeggieTales Movie', 'The Lord of the Rings: The Two Towers', 'The Lord of the Rings: The Return of the King', 'Suicide Squad', 'The Mortal Instruments: City of Bones', 'Thor: The Dark World', 'Batman v Superman: Dawn of Justice', 'Red Sonja', 'The Forbidden Kingdom', 'Maleficent', 'The Mummy: Tomb of the Dragon Emperor', 'Teenage Mutant Ninja Turtles', 'Sheena', 'G-Force', 'The Last Witch Hunter', 'The Lord of the Rings: The Fellowship of the Ring', 'Spider-Man 3', 'Race to Witch Mountain', 'The Hobbit: An Unexpected Journey', 'Teenage Mutant Ninja Turtles III', 'Night at the Museum', 'Mighty Joe Young', 'Superman II', 'Teenage Mutant Ninja Turtles: Out of the Shadows'}

# %%
q = prolog.query("find_sim_4('Thor',Y)")
s = set()
for sol in q: 
  s.add(sol['Y'])
q.close()
print(s)
# Out:
# {'Jack Ryan: Shadow Recruit', 'Much Ado About Nothing', 'The Magic Flute', 'Henry V', 'Hamlet', 'Cinderella', 'Thor: The Dark World'}

# %% [markdown]
# # **2ο Μέρος: Recommendation System με βάση μόνο τα χαρακτηριστικά των ταινιών.**
#
# Στο σημείο αυτό με βάση τους κανόνες που κατασκευάστηκαν στο Μέρος 1 θα κατασκευαστούν κατηγορήματα για την ομοιότητα ταινιών. Παρακάτω δίνεται ένα μικρό παράδειγμα ενός κανόνα και πώς αυτός θα μπορούσε να γραφτεί μέσω του Pyswip. Επίσης όπως αναφέρεται και σε σχόλιο παραπάνω θα μπορεί να γραφτεί και μια βάση δεδομένων με τους κανόνες και να γίνει απευθείας consult.
#
# Στο παρακάτω παράδειγμα το 5 και το 4 εκφράζουν την ομοιότητα των ταινιών π.χ. οι ταινίες που παράγονται μέσω του find_similar_5 είναι πιο όμοιες από αυτές που παράγονται μέσω του find_similar_4.

# %%
def simple_recommender(movie):
    s = set()
    index = []
    for i in (5, 4, 3, 2, 1):
        q = prolog.query("find_sim_" + str(i) + "('" + movie +"', M)")
        for sol in q:
            m = sol['M'] 
            if m not in s:
              s.add(sol['M'])
              index.append(i)
        q.close()
    return list(zip(s, index))

# %%
list(simple_recommender('Avatar'))
# Out:
# [('Hancock', 5),
#  ('Never Say Never Again', 5),
#  ('Heavenly Creatures', 5),
#  ('Unknown', 5),
#  ('The Dukes of Hazzard', 5),
#  ('Mr. Peabody & Sherman', 5),
#  ('Journey to the Center of the Earth', 4),
#  ('Checkmate', 4),
#  ('Hit & Run', 3),
#  ('Vertical Limit', 3),
#  ('The One', 3),
#  ('Centurion', 3),
#  ('The Huntsman: Winters War', 3),
#  ('The Adventures of Pluto Nash', 3),
#  ('The Good Dinosaur', 3),
#  ('Rockaway', 2),
#  ('First Knight', 2),
#  ('Virtuosity', 2),
#  ('Pandorum', 2),
#  ('Hot Rod', 2),
#  ('Beasts of the Southern Wild', 2),
#  ('Flatliners', 2),
#  ('Jason Bourne', 2),
#  ('Young Sherlock Holmes', 2),
#  ('Kicks', 2),
#  ('Sands of Iwo Jima', 2),
#  ('The Country Bears', 2),
#  ('Big Miracle', 2),
#  ('The Man with the Iron Fists', 2),
#  ('Jack Ryan: Shadow Recruit', 2),
#  ('Son of the Mask', 2),
#  ('Austin Powers: International Man of Mystery', 2),
#  ('Rush Hour 2', 2),
#  ('District 9', 2),
#  ('The Giver', 2),
#  ('Slither', 2),
#  ('Ride Along 2', 2),
#  ('An American Carol', 2),
#  ('The Wild Thornberrys Movie', 2),
#  ('The Adjustment Bureau', 2),
#  ('Ronin', 2),
#  ('The Covenant', 2),
#  ('The SpongeBob Movie: Sponge Out of Water', 2),
#  ('The Astronaut Farmer', 2),
#  ('The Hunger Games: Mockingjay - Part 1', 2),
#  ('Charlies Angels', 2),
#  ('Star Trek II: The Wrath of Khan', 2),
#  ('Northfork', 2),
#  ('Max Payne', 2),
#  ('Avengers: Age of Ultron', 2),
#  ('Sleep Dealer', 2),
#  ('Kiss of the Dragon', 2),
#  ('Alien', 2),
#  ('Fled', 2),
#  ('Harry Brown', 2),
#  ('eXistenZ', 2),
#  ('Cars', 2),
#  ('Conquest of the Planet of the Apes', 2),
#  ('Tuck Everlasting', 2),
#  ('The Death and Life of Bobby Z', 2),
#  ('The Purge: Election Year', 2),
#  ('The Time Machine', 2),
#  ('True Romance', 2),
#  ('The Specialist', 2),
#  ('Crouching Tiger, Hidden Dragon', 2),
#  ('Star Trek: Generations', 2),
#  ('Touching the Void', 2),
#  ('The Ballad of Cable Hogue', 2),
#  ('One for the Money', 2),
#  ('Smokin Aces', 2),
#  ('The Sorcerers Apprentice', 2),
#  ('Once Upon a Time in Mexico', 2),
#  ('Open Road', 2),
#  ('Lara Croft: Tomb Raider', 2),
#  ('Ultraviolet', 2),
#  ('The Nutcracker', 2),
#  ('The Ice Storm', 2),
#  ('Ted', 2),
#  ('Ready to Rumble', 2),
#  ('Hot Tub Time Machine', 2),
#  ('127 Hours', 2),
#  ('I Dreamed of Africa', 2),
#  ('Corky Romano', 2),
#  ('Beautiful Creatures', 2),
#  ('Chappie', 2),
#  ('Epic', 2),
#  ('Changing Lanes', 2),
#  ('Dance Flick', 2),
#  ('Live Free or Die Hard', 2),
#  ('Live and Let Die', 2),
#  ('The Beast from 20,000 Fathoms', 2),
#  ('Midnight Run', 2),
#  ('The Crazies', 2),
#  ('Only the Strong', 2),
#  ('The Incredible Hulk', 2),
#  ('Dune', 2),
#  ('Chill Factor', 2),
#  ('The Thirteenth Floor', 2),
#  ('Max Keebles Big Move', 2),
#  ('After Earth', 2),
#  ('True Lies', 2),
#  ('Baby Geniuses', 2),
#  ('Allegiant', 2),
#  ('Zathura: A Space Adventure', 2),
#  ('Thor: The Dark World', 2),
#  ('Casino Royale', 2),
#  ('Deterrence', 2),
#  ('Kung Pow: Enter the Fist', 2),
#  ('Agent Cody Banks', 2),
#  ('I Am Wrath', 2),
#  ('Sabotage', 2),
#  ('Inception', 2),
#  ('Red Dawn', 2),
#  ('Eternal Sunshine of the Spotless Mind', 2),
#  ('Robin and Marian', 2),
#  ('Ghost', 2),
#  ('The Quiet American', 2),
#  ('G-Force', 2),
#  ('Journey to Saturn', 2),
#  ('Enders Game', 2),
#  ('The Darkest Hour', 2),
#  ('Domino', 2),
#  ('What Dreams May Come', 2),
#  ('Kung Fu Hustle', 2),
#  ('3000 Miles to Graceland', 2),
#  ('First Blood', 2),
#  ('Tropic Thunder', 2),
#  ('All About the Benjamins', 2),
#  ('Split Second', 2),
#  ('Metropolis', 2),
#  ('Pixels', 2),
#  ('Underworld: Rise of the Lycans', 2),
#  ('Doomsday', 2),
#  ('The Adventures of Sharkboy and Lavagirl', 2),
#  ('Batman Begins', 2),
#  ('2012', 2),
#  ('Cellular', 2),
#  ('Warlock: The Armageddon', 2),
#  ('The Island of Dr. Moreau', 2),
#  ('The Last Days on Mars', 2),
#  ('Safe', 2),
#  ('The Kid', 2),
#  ('The World Is Not Enough', 2),
#  ('Cliffhanger', 2),
#  ('Wild Target', 2),
#  ('Paul Blart: Mall Cop 2', 2),
#  ('Green Street Hooligans: Underground', 2),
#  ('Underclassman', 2),
#  ('Night at the Museum: Battle of the Smithsonian', 2),
#  ('The Amazing Spider-Man', 2),
#  ('The First Great Train Robbery', 2),
#  ('Nothing', 2),
#  ('Rubber', 2),
#  ('Bad Boys', 2),
#  ('Vampires', 2),
#  ('Elf', 2),
#  ('Ice Age: The Meltdown', 2),
#  ('Mission: Impossible', 2),
#  ('Mission to Mars', 2),
#  ('Bullets Over Broadway', 2),
#  ('The Running Man', 2),
#  ('RoboCop', 2),
#  ('Queen of the Mountains', 2),
#  ('Def-Con 4', 2),
#  ('The Other Guys', 2),
#  ('Harry Potter and the Order of the Phoenix', 2),
#  ('The Greatest Show on Earth', 2),
#  ('I Am Legend', 2),
#  ('Mad City', 2),
#  ('Exodus: Gods and Kings', 2),
#  ('Star Wars: Episode II - Attack of the Clones', 2),
#  ('Good Kill', 2),
#  ('Troy', 2),
#  ('Cirque du Soleil: Worlds Away', 2),
#  ('To Die For', 2),
#  ('Dances with Wolves', 2),
#  ('X-Men: Apocalypse', 2),
#  ('Goosebumps', 2),
#  ('Shanghai Surprise', 2),
#  ('Aliens vs Predator: Requiem', 2),
#  ('Jaws: The Revenge', 2),
#  ('Reign of Assassins', 2),
#  ('Up', 2),
#  ('Spy Kids 3-D: Game Over', 2),
#  ('Walking Tall', 2),
#  ('Babe: Pig in the City', 2),
#  ('Nanny McPhee', 2),
#  ('Kingdom of the Spiders', 2),
#  ('The Last Stand', 2),
#  ('3 Days to Kill', 2),
#  ('Love & Basketball', 2),
#  ('Gods of Egypt', 2),
#  ('Stargate: The Ark of Truth', 2),
#  ('Bill & Teds Bogus Journey', 2),
#  ('DragonHeart', 2),
#  ('The Good, The Bad, The Weird', 2),
#  ('George and the Dragon', 2),
#  ('My Super Ex-Girlfriend', 2),
#  ('Little Nicky', 2),
#  ('Super', 2),
#  ('Miss Congeniality', 2),
#  ('Red Sky', 2),
#  ('Abduction', 2),
#  ('Kate & Leopold', 2),
#  ('Flash Gordon', 2),
#  ('Megiddo: The Omega Code 2', 2),
#  ('Inkheart', 2),
#  ('Alexander', 2),
#  ('GoldenEye', 2),
#  ('Red State', 2),
#  ('Moon', 2),
#  ('Evil Dead II', 2),
#  ('The Island', 2),
#  ('The Lord of the Rings: The Two Towers', 2),
#  ('Run All Night', 2),
#  ('Jackass Number Two', 2),
#  ('Pacific Rim', 2),
#  ('Red Sonja', 2),
#  ('March or Die', 2),
#  ('The Mechanic', 2),
#  ('Jungle Shuffle', 2),
#  ('Return to Oz', 2),
#  ('Donnie Darko', 2),
#  ('Flushed Away', 2),
#  ('I Got the Hook Up', 2),
#  ('The Princess Bride', 2),
#  ('White Noise 2: The Light', 2),
#  ('The Lord of the Rings: The Fellowship of the Ring', 2),
#  ('The Call of Cthulhu', 2),
#  ('Point Break', 2),
#  ('The Cold Light of Day', 2),
#  ('The Negotiator', 2),
#  ('Subconscious', 2),
#  ('Loves Abiding Joy', 2),
#  ('3 Strikes', 2),
#  ('Max', 2),
#  ('Rampage', 2),
#  ('Mad Max', 2),
#  ('The Walking Deceased', 2),
#  ('From Dusk Till Dawn', 2),
#  ('Punisher: War Zone', 2),
#  ('Transformers: Revenge of the Fallen', 2),
#  ('Epic Movie', 2),
#  ('We Were Soldiers', 2),
#  ('Paparazzi', 2),
#  ('Dr. Dolittle 2', 2),
#  ('Laws of Attraction', 2),
#  ('Takers', 2),
#  ('Invasion U.S.A.', 2),
#  ('Rush', 2),
#  ('Shadow Conspiracy', 2),
#  ('The 6th Day', 2),
#  ('Catch a Fire', 2),
#  ('Harley Davidson and the Marlboro Man', 2),
#  ('The Count of Monte Cristo', 2),
#  ('Across the Universe', 2),
#  ('Contact', 2),
#  ('Tracker', 2),
#  ('Conspiracy Theory', 2),
#  ('Mission: Impossible III', 2),
#  ('Kingdom of Heaven', 2),
#  ('Faster', 2),
#  ('2 Guns', 2),
#  ('Airborne', 2),
#  ('Keanu', 2),
#  ('Creature', 2),
#  ('MacGruber', 2),
#  ('Hugo', 2),
#  ('The Adventures of Pinocchio', 2),
#  ('Perrier’s Bounty', 2),
#  ('Immortals', 2),
#  ('The Last Shot', 2),
#  ('Nerve', 2),
#  ('The Craft', 2),
#  ('Captain America: The First Avenger', 2),
#  ('The Invasion', 2),
#  ('Lucky Break', 2),
#  ('Dragon Nest: Warriors Dawn', 2),
#  ('Duma', 2),
#  ('X-Men', 2),
#  ('The Illusionist', 2),
#  ('The Medallion', 2),
#  ('Swordfish', 1),
#  ('Deadpool', 1),
#  ('Six Days Seven Nights', 1),
#  ('Royal Kill', 1),
#  ('Are We There Yet?', 1),
#  ('Love Me Tender', 1),
#  ('Corpse Bride', 1),
#  ('Jimmy Neutron: Boy Genius', 1),
#  ('Timeline', 1),
#  ('Speed Racer', 1),
#  ('The Mummy Returns', 1),
#  ('The Croods', 1),
#  ('Wrath of the Titans', 1),
#  ('The Losers', 1),
#  ('The Walk', 1),
#  ('The Age of Adaline', 1),
#  ('A Low Down Dirty Shame', 1),
#  ('Harold & Kumar Go to White Castle', 1),
#  ('White House Down', 1),
#  ('The Postman', 1),
#  ('Being John Malkovich', 1),
#  ('Mr. & Mrs. Smith', 1),
#  ('Bedazzled', 1),
#  ('Puss in Boots', 1),
#  ('Run Lola Run', 1),
#  ('Wolves', 1),
#  ('Bubba Ho-tep', 1),
#  ('The Visitors', 1),
#  ('Thunder and the House of Magic', 1),
#  ('Bad Company', 1),
#  ('Decoys', 1),
#  ('Penguins of Madagascar', 1),
#  ('Mutant World', 1),
#  ('Self/less', 1),
#  ('X-Men Origins: Wolverine', 1),
#  ('Robin Hood: Prince of Thieves', 1),
#  ('The Last Samurai', 1),
#  ('Grosse Pointe Blank', 1),
#  ('Fighting Tommy Riley', 1),
#  ('Lake Placid', 1),
#  ('Lifeforce', 1),
#  ('The Last Castle', 1),
#  ('The Equalizer', 1),
#  ('Wyatt Earp', 1),
#  ('The Messenger: The Story of Joan of Arc', 1),
#  ('Batman Forever', 1),
#  ('Speed 2: Cruise Control', 1),
#  ('A Simple Wish', 1),
#  ('Travellers and Magicians', 1),
#  ('Somewhere in Time', 1),
#  ('Point Blank', 1),
#  ('Underdogs', 1),
#  ('K-PAX', 1),
#  ('Hollywood Homicide', 1),
#  ('The Marine', 1),
#  ('Act of Valor', 1),
#  ('Suicide Squad', 1),
#  ('Asterix at the Olympic Games', 1),
#  ('Foodfight!', 1),
#  ('Nancy Drew', 1),
#  ('The Day After Tomorrow', 1),
#  ('Stake Land', 1),
#  ('Troop Beverly Hills', 1),
#  ('The Chronicles of Riddick', 1),
#  ('I Origins', 1),
#  ('The Spirit', 1),
#  ('Silmido', 1),
#  ('S.W.A.T.', 1),
#  ('The Newton Boys', 1),
#  ('Impostor', 1),
#  ('Letters to God', 1),
#  ('1941', 1),
#  ('The Glimmer Man', 1),
#  ('Legend of the Guardians: The Owls of GaHoole', 1),
#  ('The Art of War', 1),
#  ('The Bourne Legacy', 1),
#  ('The Last of the Mohicans', 1),
#  ('Krampus', 1),
#  ('Time Bandits', 1),
#  ('Mortal Kombat', 1),
#  ('Fortress', 1),
#  ('The Road', 1),
#  ('Paycheck', 1),
#  ('Octopussy', 1),
#  ('The Santa Clause', 1),
#  ('Hud', 1),
#  ('Lethal Weapon 3', 1),
#  ('The Signal', 1),
#  ('The Rock', 1),
#  ('2046', 1),
#  ('Tora! Tora! Tora!', 1),
#  ('Wristcutters: A Love Story', 1),
#  ('A.I. Artificial Intelligence', 1),
#  ('Bandits', 1),
#  ('Gun Shy', 1),
#  ('The Last Legion', 1),
#  ('The Expendables 3', 1),
#  ('Dawn of the Planet of the Apes', 1),
#  ('Deuces Wild', 1),
#  ('The Pink Panther', 1),
#  ('Harry Potter and the Goblet of Fire', 1),
#  ('Scarface', 1),
#  ('Hollow Man', 1),
#  ('Elite Squad', 1),
#  ('Shipwrecked', 1),
#  ('Pocahontas', 1),
#  ('Drumline', 1),
#  ('Scott Pilgrim vs. the World', 1),
#  ('Bait', 1),
#  ('Conan the Destroyer', 1),
#  ('Mad Max 2: The Road Warrior', 1),
#  ('Queen of the Damned', 1),
#  ('The Peacemaker', 1),
#  ('The Brothers Bloom', 1),
#  ('Sky Captain and the World of Tomorrow', 1),
#  ('All Is Lost', 1),
#  ('The Incredibles', 1),
#  ('The Score', 1),
#  ('Beowulf', 1),
#  ('Bedtime Stories', 1),
#  ('Class of 1984', 1),
#  ('Shark Tale', 1),
#  ('The Man from Snowy River', 1),
#  ('Snow White and the Huntsman', 1),
#  ('The Hunger Games', 1),
#  ('Pirates of the Caribbean: Dead Mans Chest', 1),
#  ('Alvin and the Chipmunks: The Road Chip', 1),
#  ('Lucky Numbers', 1),
#  ('The Twilight Saga: Breaking Dawn - Part 2', 1),
#  ('Jurassic Park III', 1),
#  ('The Hobbit: The Desolation of Smaug', 1),
#  ('The Monuments Men', 1),
#  ('Battlefield Earth', 1),
#  ('Extreme Ops', 1),
#  ('The Rage: Carrie 2', 1),
#  ('Chain Reaction', 1),
#  ('Warriors of Virtue', 1),
#  ('Out of the Furnace', 1),
#  ('The Forsaken', 1),
#  ('In Too Deep', 1),
#  ('Ghost Rider', 1),
#  ('Ice Age', 1),
#  ('Salt', 1),
#  ('Spaceballs', 1),
#  ('Jurassic World', 1),
#  ('Breakdown', 1),
#  ('In the Name of the King: A Dungeon Siege Tale', 1),
#  ('Sky High', 1),
#  ('From Russia with Love', 1),
#  ('Zombie Hunter', 1),
#  ('The Quick and the Dead', 1),
#  ('The Four Feathers', 1),
#  ('Man of Steel', 1),
#  ('The Muppet Movie', 1),
#  ('The Guard', 1),
#  ('Cinderella', 1),
#  ('Undercover Brother', 1),
#  ('Without a Paddle', 1),
#  ('Johnny English Reborn', 1),
#  ('Krull', 1),
#  ('The Boondock Saints', 1),
#  ('Superman Returns', 1),
#  ('Total Recall', 1),
#  ('Road Trip', 1),
#  ('Bathory: Countess of Blood', 1),
#  ('Just Like Heaven', 1),
#  ('State of Play', 1),
#  ('Legends of the Fall', 1),
#  ('Dylan Dog: Dead of Night', 1),
#  ('Pan', 1),
#  ('The NeverEnding Story', 1),
#  ('Death Becomes Her', 1),
#  ('Atlas Shrugged Part III: Who is John Galt?', 1),
#  ('Why I Did (Not) Eat My Father', 1),
#  ('London', 1),
#  ('Vanilla Sky', 1),
#  ('George of the Jungle', 1),
#  ('Nothing to Lose', 1),
#  ('Queen Crab', 1),
#  ('Lone Survivor', 1),
#  ('Con Air', 1),
#  ('Jonah Hex', 1),
#  ('The Legend of Drunken Master', 1),
#  ('Supernova', 1),
#  ('The Black Stallion', 1),
#  ('Race to Witch Mountain', 1),
#  ('Die Another Day', 1),
#  ('Wild Wild West', 1),
#  ('Mighty Joe Young', 1),
#  ('Blackthorn', 1),
#  ('Space Jam', 1),
#  ('Force 10 from Navarone', 1),
#  ('Hidalgo', 1),
#  ('The Green Hornet', 1),
#  ('Knowing', 1),
#  ('Highway', 1),
#  ('The Bourne Identity', 1),
#  ('Waterworld', 1),
#  ('Rise of the Planet of the Apes', 1),
#  ('Steel', 1),
#  ('Austin Powers in Goldmember', 1),
#  ('The Brothers Grimm', 1),
#  ('Dragonslayer', 1),
#  ('The Tempest', 1),
#  ('Jason X', 1),
#  ('Disturbing Behavior', 1),
#  ('Digimon: The Movie', 1),
#  ('Street Fighter: The Legend of Chun-Li', 1),
#  ('Kill Bill: Vol. 2', 1),
#  ('Grindhouse', 1),
#  ('Dark Shadows', 1),
#  ('CJ7', 1),
#  ('Catch That Kid', 1),
#  ('C.H.U.D.', 1),
#  ('The Smurfs 2', 1),
#  ('Resident Evil', 1),
#  ('Fight Valley', 1),
#  ('Madison', 1),
#  ('Shrek 2', 1),
#  ('Unbreakable', 1),
#  ('Peggy Sue Got Married', 1),
#  ('You Dont Mess with the Zohan', 1),
#  ('Non-Stop', 1),
#  ('Into the Grizzly Maze', 1),
#  ('Bridge to Terabithia', 1),
#  ('Phenomenon', 1),
#  ('Beverly Hills Chihuahua', 1),
#  ('The Barbarians', 1),
#  ('Flubber', 1),
#  ('The Little Prince', 1),
#  ('The Hobbit: The Battle of the Five Armies', 1),
#  ('Womb', 1),
#  ('Lara Croft Tomb Raider: The Cradle of Life', 1),
#  ('Journey 2: The Mysterious Island', 1),
#  ('Terminator Genisys', 1),
#  ('Machine Gun McCain', 1),
#  ('The Fugitive', 1),
#  ('The Words', 1),
#  ('Disaster Movie', 1),
#  ('Sex Drive', 1),
#  ('Black Rain', 1),
#  ('Die Hard: With a Vengeance', 1),
#  ('Firefox', 1),
#  ('Heist', 1),
#  ('Return to the Blue Lagoon', 1),
#  ('Valiant', 1),
#  ('Harold & Kumar Escape from Guantanamo Bay', 1),
#  ('Crank: High Voltage', 1),
#  ('The Lovers', 1),
#  ('In the Heart of the Sea', 1),
#  ('The Thing', 1),
#  ('Saving Private Perez', 1),
#  ('Fetching Cody', 1),
#  ('Cotton Comes to Harlem', 1),
#  ('Tank Girl', 1),
#  ('VeggieTales: The Pirates Who Dont Do Anything', 1),
#  ('Detention', 1),
#  ('Nowhere to Run', 1),
#  ('Silverado', 1),
#  ('The Shadow', 1),
#  ('Tango & Cash', 1),
#  ('The Brain That Wouldnt Die', 1),
#  ('The Triplets of Belleville', 1),
#  ('Bangkok Dangerous', 1),
#  ('The Iron Giant', 1),
#  ('Munich', 1),
#  ('AVP: Alien vs. Predator', 1),
#  ('Perfume: The Story of a Murderer', 1),
#  ('Alien Zone', 1),
#  ('X-Men: Days of Future Past', 1),
#  ('Æon Flux', 1),
#  ('Sinbad: Legend of the Seven Seas', 1),
#  ('Back to the Future Part III', 1),
#  ('Gangsters Paradise: Jerusalema', 1),
#  ('Flight of the Phoenix', 1),
#  ('Poseidon', 1),
#  ('Blade: Trinity', 1),
#  ('Harry Potter and the Half-Blood Prince', 1),
#  ('Enter the Void', 1),
#  ('Drive Hard', 1),
#  ('The Visitors II: The Corridors of Time', 1),
#  ('Invaders from Mars', 1),
#  ('The Long Kiss Goodnight', 1),
#  ('Galaxy Quest', 1),
#  ('How the Grinch Stole Christmas', 1),
#  ('Mars Attacks!', 1),
#  ('The Cat in the Hat', 1),
#  ('The Transporter Refueled', 1),
#  ('Valley of the Wolves: Iraq', 1),
#  ('Hardflip', 1),
#  ('Under the Skin', 1),
#  ('Year One', 1),
#  ('Project Almanac', 1),
#  ('The Rundown', 1),
#  ('The Mummy: Tomb of the Dragon Emperor', 1),
#  ('Idiocracy', 1),
#  ('Its a Mad, Mad, Mad, Mad World', 1),
#  ('Rise of the Guardians', 1),
#  ('The Last Godfather', 1),
#  ('The Patriot', 1),
#  ('Fantastic Mr. Fox', 1),
#  ('The Love Letter', 1),
#  ('The Replacement Killers', 1),
#  ('Spider-Man 3', 1),
#  ('Time Changer', 1),
#  ('Pain & Gain', 1),
#  ('Gentlemen Broncos', 1),
#  ('Along Came a Spider', 1),
#  ('Hells Angels', 1),
#  ('Repo Men', 1),
#  ('Edward Scissorhands', 1),
#  ('Good Boy!', 1),
#  ('Nighthawks', 1),
#  ('Titanic', 1),
#  ('Spy Game', 1),
#  ('The Expendables', 1),
#  ('Sherlock Holmes: A Game of Shadows', 1),
#  ('World War Z', 1),
#  ('Quarantine', 1),
#  ('Titan A.E.', 1),
#  ('On Deadly Ground', 1),
#  ('Highlander: Endgame', 1),
#  ('Click', 1),
#  ('Attack the Block', 1),
#  ('Megaforce', 1),
#  ('A Lonely Place to Die', 1),
#  ('The Bounty Hunter', 1),
#  ('The Host', 1),
#  ('Guardians of the Galaxy', 1),
#  ('Muppets Most Wanted', 1),
#  ('All Superheroes Must Die', 1),
#  ('The Last Dragon', 1),
#  ('Predators', 1),
#  ('Indiana Jones and the Kingdom of the Crystal Skull', 1),
#  ('The Man from Earth', 1),
#  ('Exorcist II: The Heretic', 1),
#  ('Crocodile Dundee', 1),
#  ('The X Files: I Want to Believe', 1),
#  ('Hocus Pocus', 1),
#  ('A Passage to India', 1),
#  ('Mad Max: Fury Road', 1),
#  ('The Family Man', 1),
#  ('The Black Hole', 1),
#  ('Godzilla 2000', 1),
#  ('Cat People', 1),
#  ('Exit Wounds', 1),
#  ('Into the Wild', 1),
#  ('Snow White: A Tale of Terror', 1),
#  ('The Flintstones', 1),
#  ('The Odd Life of Timothy Green', 1),
#  ('Drive', 1),
#  ('Kung Fu Panda 3', 1),
#  ('Barbarella', 1),
#  ('Airlift', 1),
#  ('Born Of War', 1),
#  ('Capricorn One', 1),
#  ('Batman Returns', 1),
#  ('Skyfall', 1),
#  ('Timecop', 1),
#  ('Wicked Blood', 1),
#  ('The Santa Clause 2', 1),
#  ('Enter Nowhere', 1),
#  ('Alien: Resurrection', 1),
#  ('Shanghai Noon', 1),
#  ('American Sniper', 1),
#  ('The I Inside', 1),
#  ('Hero', 1),
#  ('Triple 9', 1),
#  ('Cypher', 1),
#  ('Armageddon', 1),
#  ('The Boxtrolls', 1),
#  ('Benji', 1),
#  ('The Amazing Spider-Man 2', 1),
#  ('The Sisterhood of the Traveling Pants 2', 1),
#  ('Terminator Salvation', 1),
#  ('Blade Runner', 1),
#  ('The Three Musketeers', 1),
#  ('Spy Kids', 1),
#  ('Shanghai Knights', 1),
#  ('The Devils Double', 1),
#  ('Sphinx', 1),
#  ('Mission: Impossible - Rogue Nation', 1),
#  ('The Warriors Way', 1),
#  ('Stripes', 1),
#  ('The Sum of All Fears', 1),
#  ('Six-String Samurai', 1),
#  ('Supercross', 1),
#  ('Paul', 1),
#  ('Seven Samurai', 1),
#  ('Dracula Untold', 1),
#  ('G.I. Joe: The Rise of Cobra', 1),
#  ('Bee Movie', 1),
#  ('Mirror Mirror', 1),
#  ('The Fourth Kind', 1),
#  ('Lone Wolf McQuade', 1),
#  ('The Beach', 1),
#  ('Elektra', 1),
#  ('Dredd', 1),
#  ('The Jacket', 1),
#  ('Her', 1),
#  ('The Nutty Professor', 1),
#  ('The November Man', 1),
#  ('The Order', 1),
#  ('H.', 1),
#  ('Bullet to the Head', 1),
#  ('Serenity', 1),
#  ('Kickboxer: Vengeance', 1),
#  ('Stolen', 1),
#  ('Kill Bill: Vol. 1', 1),
#  ('Petes Dragon', 1),
#  ('Romeo Must Die', 1),
#  ('Ransom', 1),
#  ('RockNRolla', 1),
#  ('Micmacs', 1),
#  ('Bloodsport', 1),
#  ('Ice Age: Continental Drift', 1),
#  ('Soul Surfer', 1),
#  ('Ip Man 3', 1),
#  ('Machine Gun Preacher', 1),
#  ('Drive Angry', 1),
#  ('Scooby-Doo', 1),
#  ('Big Hero 6', 1),
#  ('Pompeii', 1),
#  ('The Smurfs', 1),
#  ('Alive', 1),
#  ('The Hunting Party', 1),
#  ('Bogus', 1),
#  ('Money Talks', 1),
#  ('Spirited Away', 1),
#  ('Flipper', 1),
#  ('The Good Night', 1),
#  ('The Pacifier', 1),
#  ('The Devils Tomb', 1),
#  ('The Fast and the Furious: Tokyo Drift', 1),
#  ('X-Men: First Class', 1),
#  ('Clockstoppers', 1),
#  ('1911', 1),
#  ('Nebraska', 1),
#  ('From Paris with Love', 1),
#  ('The Wolverine', 1),
#  ('Operation Chromite', 1),
#  ('Independence Day', 1),
#  ('Pineapple Express', 1),
#  ('Baahubali: The Beginning', 1),
#  ('This Means War', 1),
#  ('The Golden Child', 1),
#  ('The Great Raid', 1),
#  ('The Empire Strikes Back', 1),
#  ('The Wraith', 1),
#  ('Moby Dick', 1),
#  ('Rotor DR1', 1),
#  ('Astro Boy', 1),
#  ('Parker', 1),
#  ('Krrish', 1),
#  ('Close Encounters of the Third Kind', 1),
#  ('The Young and Prodigious T.S. Spivet', 1),
#  ('Zambezia', 1),
#  ('Looper', 1),
#  ('Licence to Kill', 1),
#  ('Godsend', 1),
#  ('Close Range', 1),
#  ('Resident Evil: Extinction', 1),
#  ('The Legend of Bagger Vance', 1),
#  ('Monte Carlo', 1),
#  ('Tidal Wave', 1),
#  ('El Mariachi', 1),
#  ('Heavens Gate', 1),
#  ('Oldboy', 1),
#  ('Minority Report', 1),
#  ('The Yards', 1),
#  ('Chicago', 1),
#  ('Find Me Guilty', 1),
#  ('G.I. Joe: Retaliation', 1),
#  ('Left Behind', 1),
#  ('War', 1),
#  ('Pootie Tang', 1),
#  ('The Italian Job', 1),
#  ('The Helix... Loaded', 1),
#  ('The Curse of the Were-Rabbit', 1),
#  ('Cop Land', 1),
#  ('Like Mike', 1),
#  ('Face/Off', 1),
#  ('Beyond Borders', 1),
#  ('Alvin and the Chipmunks', 1),
#  ('Home', 1),
#  ('Repo! The Genetic Opera', 1),
#  ('Hot Pursuit', 1),
#  ('Collateral Damage', 1),
#  ('Dark City', 1),
#  ('The Secret Life of Walter Mitty', 1),
#  ('Blades of Glory', 1),
#  ('The Charge of the Light Brigade', 1),
#  ('D-Tox', 1),
#  ('The Tree of Life', 1),
#  ('Joe Dirt', 1),
#  ('3 Ninjas Kick Back', 1),
#  ('A Man Apart', 1),
#  ('The Hunted', 1),
#  ('The Specials', 1),
#  ('The Net', 1),
#  ('The Brave Little Toaster', 1),
#  ('The Chronicles of Narnia: The Voyage of the Dawn Treader', 1),
#  ('What Planet Are You From?', 1),
#  ('Whats the Worst That Could Happen?', 1),
#  ('The Wiz', 1),
#  ('Die Hard', 1),
#  ('Renaissance', 1),
#  ('Alex Cross', 1),
#  ('Proof of Life', 1),
#  ('The Faculty', 1),
#  ('Annie Get Your Gun', 1),
#  ('Shrek the Third', 1),
#  ('The Lawnmower Man', 1),
#  ('Raise the Titanic', 1),
#  ('Whiteout', 1),
#  ('Meet Dave', 1),
#  ('Roar', 1),
#  ('Monsters', 1),
#  ('Three Kingdoms: Resurrection of the Dragon', 1),
#  ('2001: A Space Odyssey', 1),
#  ('The Grandmaster', 1),
#  ('Stardust', 1),
#  ('Screwed', 1),
#  ('Never Let Me Go', 1),
#  ('E.T. the Extra-Terrestrial', 1),
#  ('The Indian in the Cupboard', 1),
#  ('Species', 1),
#  ('About Time', 1),
#  ('Die Hard 2', 1),
#  ('Aladdin', 1),
#  ('Terminator 2: Judgment Day', 1),
#  ('Return of the Living Dead 3', 1),
#  ('Universal Soldier: The Return', 1),
#  ('Mortdecai', 1),
#  ('Silent Running', 1),
#  ('Kung Fu Panda', 1),
#  ('New Nightmare', 1),
#  ('The Tuxedo', 1),
#  ('Bolt', 1),
#  ('The Matrix', 1),
#  ('Its a Wonderful Life', 1),
#  ('The Haunting', 1),
#  ('The Musketeer', 1),
#  ('The Sticky Fingers of Time', 1),
#  ('American Heist', 1),
#  ('The Mighty Macs', 1),
#  ('The Crew', 1),
#  ('Chronicle', 1),
#  ('Snakes on a Plane', 1),
#  ('Kites', 1),
#  ('Creative Control', 1),
#  ('Deep Rising', 1),
#  ('The Cave', 1),
#  ('Mirrormask', 1),
#  ('Southpaw', 1),
#  ('Sound of My Voice', 1),
#  ('The Lost Medallion: The Adventures of Billy Stone', 1),
#  ('Super 8', 1),
#  ('Training Day', 1),
#  ('One Mans Hero', 1),
#  ('Monkeybone', 1),
#  ('Sliding Doors', 1),
#  ('The Mask of Zorro', 1),
#  ('Crazy Stone', 1),
#  ('This Is the End', 1),
#  ('Captain America: The Winter Soldier', 1),
#  ('The Lone Ranger', 1),
#  ('Return of the Jedi', 1),
#  ('Machete Kills', 1),
#  ('The Legend of Tarzan', 1),
#  ('Happily NEver After', 1),
#  ('Killers', 1),
#  ('Shaolin Soccer', 1),
#  ('Percy Jackson & the Olympians: The Lightning Thief', 1),
#  ('RED', 1),
#  ('Unstoppable', 1),
#  ('Now You See Me 2', 1),
#  ('Stranger Than Fiction', 1),
#  ('The Borrowers', 1),
#  ('Star Wars: Episode III - Revenge of the Sith', 1),
#  ('Logans Run', 1),
#  ('The Time Travelers Wife', 1),
#  ('Maximum Risk', 1),
#  ('Lockout', 1),
#  ('Cirque du Freak: The Vampires Assistant', 1),
#  ('Real Steel', 1),
#  ('Tremors', 1),
#  ('Anaconda', 1),
#  ('Das Boot', 1),
#  ('Jurassic Park', 1),
#  ('Legend of a Rabbit', 1),
#  ('Containment', 1),
#  ('The Adventures of Rocky & Bullwinkle', 1),
#  ('Return to Never Land', 1),
#  ('Big Trouble in Little China', 1),
#  ('Subway', 1),
#  ('Evan Almighty', 1),
#  ('Inspector Gadget', 1),
#  ('Blade', 1),
#  ('The Lego Movie', 1),
#  ('Double Take', 1),
#  ('Dragonball Evolution', 1),
#  ('Eight Legged Freaks', 1),
#  ('Snow White and the Seven Dwarfs', 1),
#  ('Thomas and the Magic Railroad', 1),
#  ('Atlantis: The Lost Empire', 1),
#  ('The Warlords', 1),
#  ('Bon Cop Bad Cop', 1),
#  ('The Day the Earth Stood Still', 1),
#  ('Doctor Dolittle', 1),
#  ('Medicine Man', 1),
#  ('Seeking a Friend for the End of the World', 1),
#  ('In Time', 1),
#  ('The Inhabited Island', 1),
#  ('Battle: Los Angeles', 1),
#  ('Jack Brooks: Monster Slayer', 1),
#  ('Donovans Reef', 1),
#  ('Southland Tales', 1),
#  ('Charlottes Web', 1),
#  ('Scrooged', 1),
#  ('Babys Day Out', 1),
#  ('Harry Potter and the Prisoner of Azkaban', 1),
#  ('Conan the Barbarian', 1),
#  ('Firestarter', 1),
#  ('Beetlejuice', 1),
#  ('Aliens', 1),
#  ('Howls Moving Castle', 1),
#  ('Feast', 1),
#  ('Catwoman', 1),
#  ('The Hitchhikers Guide to the Galaxy', 1),
#  ('Beastmaster 2: Through the Portal of Time', 1),
#  ('How to Train Your Dragon 2', 1),
#  ('Bandidas', 1),
#  ('Splice', 1),
#  ('The Cell', 1),
#  ('The Transporter', 1),
#  ('Taken 2', 1),
#  ('The Lord of the Rings: The Return of the King', 1),
#  ('Ant-Man', 1),
#  ('Doom', 1),
#  ('Vessel', 1),
#  ('The Forbidden Kingdom', 1),
#  ('The Mist', 1),
#  ('The Train', 1),
#  ('The Way of the Gun', 1),
#  ('Akira', 1),
#  ('Hellboy', 1),
#  ('Star Trek V: The Final Frontier', 1),
#  ('Teenage Mutant Ninja Turtles', 1),
#  ('Top Gun', 1),
#  ('Survival of the Dead', 1),
#  ('G.I. Jane', 1),
#  ('The Sentinel', 1),
#  ('The Fountain', 1),
#  ('All Hat', 1),
#  ('Prophecy', 1),
#  ('Ninja Assassin', 1),
#  ('Gremlins 2: The New Batch', 1),
#  ('Captain Phillips', 1),
#  ('The Perfect Wave', 1),
#  ('D.E.B.S.', 1),
#  ('Compadres', 1),
#  ('Teenage Mutant Ninja Turtles III', 1),
#  ('Texas Rangers', 1),
#  ('Percy Jackson: Sea of Monsters', 1),
#  ('Ladyhawke', 1),
#  ('A Knights Tale', 1),
#  ('The Emperors New Groove', 1),
#  ('Colombiana', 1),
#  ('Half Past Dead', 1),
#  ('You Again', 1),
#  ('Frequency', 1),
#  ('Shinjuku Incident', 1),
#  ('Life of Pi', 1),
#  ('The Boys from Brazil', 1),
#  ('They Live', 1),
#  ('Moonraker', 1),
#  ('The Jungle Book 2', 1),
#  ('Teen Wolf Too', 1),
#  ('Taxman', 1),
#  ('The Andromeda Strain', 1),
#  ('Pirates of the Caribbean: On Stranger Tides', 1),
#  ('Hercules', 1),
#  ('16 Blocks', 1),
#  ('Quantum of Solace', 1),
#  ('Phantasm II', 1),
#  ('Lady in the Water', 1),
#  ('Ella Enchanted', 1),
#  ('The Bourne Supremacy', 1),
#  ('Victor Frankenstein', 1),
#  ('Nanny McPhee and the Big Bang', 1),
#  ('Waterloo', 1),
#  ('The Other Side of Heaven', 1),
#  ('Saints and Soldiers', 1),
#  ('Batman', 1),
#  ('Ishtar', 1),
#  ('Central Intelligence', 1),
#  ('Wolf', 1),
#  ('Highlander', 1),
#  ('Action Jackson', 1),
#  ('Never Back Down', 1),
#  ('Thunderbirds', 1),
#  ('Escape from L.A.', 1),
#  ('Frozen', 1),
#  ('The Edge', 1),
#  ('Megamind', 1),
#  ('Chicago Overcoat', 1),
#  ('Snow Dogs', 1),
#  ('Crank', 1),
#  ('Ladder 49', 1),
#  ('Delgo', 1),
#  ('Eight Below', 1),
#  ('Kiss of Death', 1),
#  ('12 Rounds', 1),
#  ('Armored', 1),
#  ('Escape Plan', 1),
#  ('I Am Number Four', 1),
#  ('Beverly Hills Cop II', 1),
#  ...]

# %% [markdown]
# # **3ο Μέρος: Recommendation System Με βάση τις προτιμήσεις-Αξιολογήσεις του χρήστη-Εκπαίδευση και Πρόβλεψη**
#
#
# Αρχικά μελετάμε τις αξιολογήσεις κάθε χρήστη για να καταλάβουμε την δομή και τις πληροφορίες κάθε αρχείου.

# %%
from tqdm.notebook import tqdm
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np
import random

rating_weights = {0: -1, 1: -0.5, 2: -0.2, 3:0, 4:0.5, 5:1}
score_weights = {1: 0.5, 2: 1, 3: 1.5, 4: 2, 5: 2.5} # ανάλογα με τα επίπεδα ομοιότητας που έχουν οριστεί στην simple_recommender

def train_recommender(ratings, rating_weights, score_weights, number_of_movies = 10):
    """
    Στην συνάρτηση αυτή μπορούμε να ορίζουμε ποιο υποσύνολο των αξιολογήσεων θα χρησιμοποιήσουμε για το train μαζί με τα βάρη ομοιότητας και σκορ
    Σε συνδυασμό με τον αριθμό των ταινιών που θέλουμε να χρησιμοποιήσουμε σαν σύνολο δεδομένων π.χ. 10 από τις 100 ή 3 από τις 100 κ.ο.κ
    Αν θέλουμε να χρησιμοποιήσουμε όλες τις ταινίες σαν training set τότε ορίζουμε το number_of_movies = - 1
    """

    if number_of_movies > len(ratings):
        number_of_movies = len(ratings)


    if number_of_movies != -1:
        indexes = random.sample(range(len(ratings)), number_of_movies)
        ratings = ratings.iloc[indexes]

    movie_score = {}
    for row in tqdm(ratings.itertuples(index=True, name='Pandas')):
        movie = clean_text(getattr(row, 'movie_title'))
        rating = getattr(row, 'rating')

        similar_movies = list(simple_recommender(movie))

        for similar_movie,i in similar_movies:
            if similar_movie not in movie_score:
                movie_score[similar_movie] = rating_weights[int(rating)] * score_weights[i]
            else:
                movie_score[similar_movie] += rating_weights[int(rating)] * score_weights[i] # το weight θα το ορίσετε ανα επίπεδο ομοιότητας οι πολύ όμοιες ταινίες θα έχουν μεγαλύτερο βάρος
    return movie_score


# Αυτό είναι ένα παράδειγμα για το πως θα μπορούσε να υλοποιήθει η predict.
# Έχουμε ορίσει ότι μια ταινία θα έπρεπε να είναι προτεινόμενη αν είχε σκορ > 0.
def predict_example(ratings, movie_score):
    real, pred = [], []
    for i, row in enumerate(ratings.itertuples(index=True, name='Pandas')):
        movie = clean_text(getattr(row, 'movie_title'))
        rating = getattr(row, 'rating')

        if movie in movie_score: #αν έχουμε σχηματίσει βαθμολογία για την ταινία αυτή
            pred.append(int(movie_score[movie] > 0)) #heuristic για το αν μια ταινία είναι προτεινόμενη
            real.append(int(rating > 3))# έτσι ορίζουμε ότι μια ταινία θα έπρεπε να είναι προτεινόμενη
            #η συνθήκη αυτή δεν μπορεί να αλλάξει
        else: #δεν μπορούμε να προτείνουμε κάτι για το όποιο δεν έχουμε σχηματίσει εικόνα
            pred.append(0)
            real.append(int(rating > 3))

    return real, pred


def get_metrics(real, pred):
    metrics = {}
    metrics["precision"] = precision_score(real, pred)
    metrics["recall"] = recall_score(real, pred)
    metrics["f1"] = f1_score(real, pred)
    return metrics

# %% [markdown]
# Η παραπάνω εκπαιδεύουν, τεστάρουν και μετρούν την απόδοσή του συστήματος στάσεων μας. Για την εκπαίδευση του συστήματος μπορούμε κάθε φορά να χρησιμοποιήσουμε ένα τυχαίο υποσύνολο του training set. Όμως είναι πιθανό το υποσύνολο των ταινιών αυτόν να επηρεάζει τα αποτελέσματα στο training set. Για παράδειγμα από 3 ταινίες στις 10 μπορούν για ένα πείραμα τα αποτελέσματα μας αν είναι ίδια και αυτό να μην οφείλεται στο γεγονός ότι ο ταξινομητής μας τα πηγαίνει καλά στις 3 ταινίες αλλά στο γεγονός ότι οι υπόλοιπες 7 είναι τέτοιες ταινίες που δεν μας βοηθούν καθόλου και αν είχαμε επιλέξει διαφορετικές 3 ταινίες να τα πηγαίναμε χάλια. Οπότε προτείνουμε να τρέξετε κάθε φορά έναν αριθμό πειραμάτων για κάθε υποσύνολο ταινιών π.χ. 10 πειράματα με 3 ταινίες, 10 πειράματα για 20 ταινίες κ.ο.κ. και να κρατήσετε σαν τελικό σκορ το μέσο όρο όλων των πειραμάτων. Έτσι τα αποτελέσματα των αγγλικών σας θα είναι πιο αντικειμενικά.

# %%
train_ratings = pd.read_csv(path + "train_ratings.csv")
test_ratings = pd.read_csv(path + "test_ratings.csv")

# %%
metrics = []
for i in range (10):
    movie_score = train_recommender(train_ratings, rating_weights, score_weights, 3)
    real, pred = predict_example(test_ratings, movie_score)
    metrics.append(get_metrics(real, pred))

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# precision: 0.4617158925148628
# recall: 0.37777777777777777
# f1: 0.34995513786554805

# %%
metrics = []
for i in range (10):
    movie_score = train_recommender(train_ratings, rating_weights, score_weights, 5)
    real, pred = predict_example(test_ratings, movie_score)
    metrics.append(get_metrics(real, pred))

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# precision: 0.5372336075825521
# recall: 0.7388888888888888
# f1: 0.5730932824435834

# %%
metrics = []
for i in range (10):
    movie_score = train_recommender(train_ratings, rating_weights, score_weights, 10)
    real, pred = predict_example(test_ratings, movie_score)
    metrics.append(get_metrics(real, pred))

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# precision: 0.5244684763852999
# recall: 0.6569444444444444
# f1: 0.5525966322805107

# %%
metrics = []
for i in range (10):
    movie_score = train_recommender(train_ratings, rating_weights, score_weights, 30)
    real, pred = predict_example(test_ratings, movie_score)
    metrics.append(get_metrics(real, pred))

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# precision: 0.5048537242321508
# recall: 0.9069444444444444
# f1: 0.6460671220651133

# %%
metrics = []
for i in range (10):
    movie_score = train_recommender(train_ratings, rating_weights, score_weights, 50)
    real, pred = predict_example(test_ratings, movie_score)
    metrics.append(get_metrics(real, pred))

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# precision: 0.5098136218218137
# recall: 0.9736111111111112
# f1: 0.6691730114706079

# %%
metrics = []
for i in range (10):
    movie_score = train_recommender(train_ratings, rating_weights, score_weights, 100)
    real, pred = predict_example(test_ratings, movie_score)
    metrics.append(get_metrics(real, pred))

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# precision: 0.5142857142857142
# recall: 1.0
# f1: 0.6792452830188679

# %% [markdown]
# Παρατηρούμε πως όσο μεγαλώνουμε το μέγεθος του training set, τόσο μεγαλύτερο είναι και το recall πλησιάζοντας τη μονάδα, ενώ το precision παραμένει σχεδόν ίδιο κοντά στο 0.5. Με άλλα λόγια, με την αύξηση του training set βελτιώνονται οι μετρικές ταξινόμησης, αφού προτείνονται στον χρήστη περισσότερες ταινίες που τον ενδιαφέρουν, αλλά ταυτόχρονα προτείνονται και περισσότερες ταινίες που δεν τον ενδιαφέρουν.
